# %%
import nltk
import os
import pandas as pd
import numpy as np
import re
import math as m
from collections import Counter
from bs4 import BeautifulSoup
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
stop_list = stopwords.words('english')

# %%
import math

# Declaring variables for file path
in_path = 'corpus'
out_path = 'prep_corpus'

# Declaring variables for query files
query = 'queries.txt'
preproc_query = 'preprocessed_queries.txt'

# %%
if not os.path.isdir(out_path):
    os.mkdir(out_path)
filenames = os.listdir(in_path)
st = PorterStemmer()
shortword = re.compile(r'\W*\b\w{1,2}\b')

# %%
print(filenames)
# Out:
# ['doc332', 'doc130', 'doc12', 'doc320', 'doc466', 'doc71', 'doc410', 'doc295', 'doc663', 'doc515', 'doc465', 'doc114', 'doc566', 'doc593', 'doc55', 'doc481', 'doc30', 'doc602', 'doc407', 'doc581', 'doc471', 'doc380', 'doc303', 'doc246', 'doc451', 'doc330', 'doc608', 'doc499', 'doc267', 'doc490', 'doc479', 'doc366', 'doc288', 'doc449', 'doc284', 'doc507', 'doc210', 'doc39', 'doc48', 'doc394', 'doc343', 'doc543', 'doc397', 'doc589', 'doc604', 'doc647', 'doc596', 'doc337', 'doc232', 'doc77', 'doc512', 'doc448', 'doc273', 'doc41', 'doc289', 'doc115', 'doc669', 'doc275', 'doc575', 'doc61', 'doc248', 'doc560', 'doc541', 'doc639', 'doc473', 'doc383', 'doc227', 'doc306', 'doc276', 'doc684', 'doc419', 'doc222', 'doc600', 'doc431', 'doc131', 'doc474', 'doc280', 'doc338', 'doc440', 'doc92', 'doc461', 'doc80', 'doc270', 'doc673', 'doc324', 'doc510', 'doc229', 'doc656', 'doc535', 'doc151', 'doc650', 'doc611', 'doc364', 'doc659', 'doc203', 'doc329', 'doc233', 'doc118', 'doc331', 'doc316', 'doc661', 'doc674', 'doc393', 'doc493', 'doc187', 'doc264', 'doc98', 'doc105', 'doc180', 'doc257', 'doc74', 'doc341', 'doc129', 'doc104', 'doc176', 'doc336', 'doc536', 'doc15', 'doc580', 'doc282', 'doc505', 'doc497', 'doc296', 'doc112', 'doc235', 'doc453', 'doc213', 'doc681', 'doc662', 'doc241', 'doc623', 'doc573', 'doc314', 'doc385', 'doc250', 'doc381', 'doc653', 'doc636', 'doc582', 'doc498', 'doc152', 'doc641', 'doc386', 'doc260', 'doc215', 'doc675', 'doc83', 'doc334', 'doc457', 'doc534', 'doc189', 'doc491', 'doc358', 'doc53', 'doc166', 'doc297', 'doc122', 'doc243', 'doc483', 'doc50', 'doc285', 'doc171', 'doc415', 'doc279', 'doc367', 'doc609', 'doc317', 'doc638', 'doc255', 'doc610', 'doc14', 'doc664', 'doc16', 'doc310', 'doc544', 'doc354', 'doc335', 'doc446', 'doc34', 'doc537', 'doc307', 'doc138', 'doc21', 'doc236', 'doc395', 'doc349', 'doc89', 'doc347', 'doc356', 'doc516', 'doc265', 'doc478', 'doc434', 'doc612', 'doc256', 'doc456', 'doc635', 'doc216', 'doc134', 'doc344', 'doc671', 'doc209', 'doc87', 'doc496', 'doc328', 'doc585', 'doc447', 'doc361', 'doc402', 'doc540', 'doc645', 'doc117', 'doc441', 'doc561', 'doc648', 'doc553', 'doc583', 'doc299', 'doc79', 'doc97', 'doc654', 'doc205', 'doc438', 'doc09', 'doc476', 'doc262', 'doc590', 'doc234', 'doc351', 'doc564', 'doc522', 'doc353', 'doc251', 'doc269', 'doc19', 'doc36', 'doc86', 'doc411', 'doc443', 'doc13', 'doc22', 'doc188', 'doc173', 'doc615', 'doc221', 'doc184', 'doc425', 'doc56', 'doc62', 'doc597', 'doc455', 'doc552', 'doc223', 'doc404', 'doc43', 'doc660', 'doc156', 'doc444', 'doc518', 'doc106', 'doc287', 'doc517', 'doc93', 'doc196', 'doc556', 'doc136', 'doc321', 'doc348', 'doc382', 'doc107', 'doc618', 'doc469', 'doc301', 'doc33', 'doc620', 'doc459', 'doc501', 'doc308', 'doc137', 'doc503', 'doc333', 'doc57', 'doc177', 'doc346', 'doc546', 'doc72', 'doc121', 'doc63', 'doc562', 'doc450', 'doc206', 'doc11', 'doc302', 'doc686', 'doc212', 'doc231', 'doc679', 'doc558', 'doc73', 'doc489', 'doc290', 'doc642', 'doc23', 'doc401', 'doc271', 'doc101', 'doc355', 'doc174', 'doc252', 'doc230', 'doc421', 'doc192', 'doc592', 'doc08', 'doc157', 'doc274', 'doc28', 'doc432', 'doc579', 'doc226', 'doc565', 'doc682', 'doc595', 'doc202', 'doc70', 'doc169', 'doc31', 'doc52', 'doc484', 'doc396', 'doc253', 'doc472', 'doc551', 'doc322', 'doc363', 'doc555', 'doc29', 'doc665', 'doc94', 'doc690', 'doc392', 'doc65', 'doc678', 'doc463', 'doc02', 'doc124', 'doc26', 'doc40', 'doc345', 'doc17', 'doc369', 'doc214', 'doc190', 'doc485', 'doc91', 'doc178', 'doc38', 'doc291', 'doc103', 'doc685', 'doc626', 'doc388', 'doc278', 'doc630', 'doc688', 'doc542', 'doc652', 'doc150', 'doc185', 'doc666', 'doc417', 'doc629', 'doc64', 'doc475', 'doc521', 'doc689', 'doc207', 'doc470', 'doc109', 'doc519', 'doc379', 'doc88', 'doc628', 'doc468', 'doc167', 'doc601', 'doc281', 'doc409', 'doc268', 'doc568', 'doc191', 'doc500', 'doc651', 'doc293', 'doc574', 'doc25', 'doc325', 'doc670', 'doc294', 'doc140', 'doc146', 'doc54', 'doc164', 'doc452', 'doc525', 'doc149', ...

# %%
print("Total Number of Documents :{}".format(len(filenames)))
# Out:
# Total Number of Documents :690

# %%
def tokenize(data):
    lines = data.lower()
    lines = re.sub('[^A-Za-z]+', ' ', lines)
    tokens = lines.split()
    clean_tokens = [word for word in tokens if word not in stop_list]
    stem_tokens = [st.stem(word) for word in clean_tokens]
    clean_stem_tokens = [word for word in stem_tokens if word not in stop_list]
    clean_stem_tokens = ' '.join(map(str,  clean_stem_tokens))
    clean_stem_tokens = shortword.sub('', clean_stem_tokens)
    return clean_stem_tokens

def extractTokens(beautSoup, tag):
    textData = beautSoup.findAll(tag)
    textData = ''.join(map(str, textData))
    textData = textData.replace(tag, '')
    textData = tokenize(textData)
    return textData

# %%
for fname in filenames:
    infilepath = in_path + '/' + fname
    outfilepath = out_path + '/' + fname
    with open(infilepath) as infile:
        with open(outfilepath, 'w') as outfile:
            fileData = infile.read()
            soup = BeautifulSoup(fileData)
            title = extractTokens(soup, 'title')
            text = extractTokens(soup, 'text')
            outfile.write(title)
            outfile.write(" ")
            outfile.write(text)
        outfile.close()
    infile.close()

# %%
all_docs = []

for fname in filenames:
    outfilepath = out_path + '/' + fname
    with open(outfilepath) as file:
        fileData = file.read()
        all_docs.append(fileData)

# %%
no_of_docs=len(all_docs)

for i in range(no_of_docs):
    tokens = all_docs[i].split()
    print(tokens)
# Out:
# ['similitud', 'hyperson', 'real', 'flow', 'slender', 'bodi', 'blunt', 'nose', 'basi', 'hyperson', 'small', 'perturb', 'theori', 'law', 'similitud', 'hyperson', 'inviscid', 'flow', 'field', 'thin', 'slender', 'bodi', 'examin', 'restrict', 'ideal', 'gase', 'constant', 'specif', 'heat', 'bodi', 'point', 'nose', 'remov', 'steadi', 'plane', 'axisymmetr', 'flow', 'consid', 'inspect', 'govern', 'system', 'equat', 'show', 'similitud', 'law', 'exist', 'flow', 'field', 'local', 'thermal', 'equilibrium', 'free', 'stream', 'atmospher', 'flow', 'ideal', 'constant', 'specif', 'heat', 'requir', 'free', 'stream', 'atmospher', 'composit', 'pressur', 'densiti', 'replac', 'requir', 'ratio', 'specif', 'heat', 'flow', 'blunt', 'wedg', 'cone', 'special', 'law', 'similitud', 'obtain', 'applic', 'similar', 'rule', 'examin', 'case', 'hyperson', 'flow', 'ideal', 'flat', 'plate', 'blunt', 'lead', 'edg', 'case', 'equilibrium', 'air', 'flow', 'wedg', 'possibl', 'simul', 'nonequilibrium', 'flow', 'slender', 'thin', 'bodi', 'also', 'point']
# ['behaviour', 'non', 'linear', 'system', 'mani', 'phenomena', 'occur', 'world', 'around', 'govern', 'nonlinear', 'relationship', 'develop', 'mathemat', 'scienc', 'difficulti', 'nonlinear', 'analysi', 'hinder', 'formul', 'nonlinear', 'concept', 'would', 'permit', 'understand', 'phenomena', 'present', 'articl', 'progress', 'understand', 'behavior', 'nonlinear', 'system', 'review', 'attempt', 'made', 'present', 'result', 'concept', 'way', 'may', 'appli', 'gener', 'problem']
# ['structur', 'aerelast', 'consider', 'high', 'speed', 'flight', 'domin', 'factor', 'structur', 'design', 'high', 'speed', 'aircraft', 'thermal', 'aeroelast', 'origin', 'subject', 'matter', 'concern', 'larg', 'discuss', 'factor', 'interrel', 'one', 'anoth', 'summari', 'present', 'analyt', 'experiment', 'tool', 'avail', 'aeronaut', 'engin', 'meet', 'demand', 'high', 'speed', 'flight', 'upon', 'aircraft', 'structur', 'state', 'art', 'respect', 'heat', 'transfer', 'boundari', 'layer', 'structur', 'mode', 'failur', 'combin', 'load', 'well', 'thermal', 'input', 'acrothermoelast', 'discuss', 'method', 'attack', 'allevi', 'structur', 'aeroelast', 'problem', 'high', 'speed', 'flight', 'summar', 'final', 'avenu', 'fundament', 'research', 'suggest']
# ['comment', 'improv', 'numer', 'solut', 'blasiu', 'problem', 'three', 'point', 'boundari', 'condit', 'attent', 'drawn', 'previou', 'accur', 'solut', 'problem']
# ['approxim', 'formula', 'thermal', 'stress', 'analysi', 'basi', 'thermal', 'stress', 'analysi', 'determin', 'temperatur', 'distribut', 'structur', 'arbitrari', 'flight', 'histori', 'determin', 'distribut', 'rather', 'tediou', 'complet', 'gener', 'latter', 'fact', 'handicap', 'optim', 'studi', 'project', 'design', 'stage', 'desir', 'abl', 'express', 'thermal', 'stress', 'distribut', 'gener', 'manner', 'note', 'gener', 'express', 'deriv', 'thermal', 'stress', 'distribut', 'typic', 'section', 'use', 'similar', 'assumpt', 'biot']
# ['placehold']
# ['effect', 'quasi', 'steadi', 'air', 'forc', 'incompress', 'bend', 'torsion', 'flutter', 'explicit', 'solut', 'obtain', 'bend', 'torsion', 'flutter', 'two', 'dimension', 'airfoil', 'incompress', 'flow', 'assumpt', 'theodorsen', 'function', 'set', 'equal', 'real', 'constant', 'diagon', 'virtual', 'mass', 'term', 'neglig', 'case', 'small', 'bend', 'torsion', 'frequenc', 'ratio', 'comparison', 'made', 'quasi', 'steadi', 'solut', 'earlier', 'empir', 'express', 'suggest', 'theodorsen', 'garrick', 'nonsteadi', 'case', 'effect', 'function', 'indic', 'import', 'locat', 'small', 'case', 'emphas', 'possibl', 'flutter', 'zero', 'air', 'speed', 'indic']
# ['effect', 'variabl', 'heat', 'recombin', 'stagnat', 'point', 'heat', 'transfer', 'earlier', 'studi', 'assum', 'averag', 'heat', 'format', 'atom', 'base', 'upon', 'extern', 'flow', 'condit', 'shown', 'equilibrium', 'heat', 'transfer', 'decreas', 'typic', 'mach', 'number', 'case', 'allow', 'made', 'proport', 'air', 'compon', 'variabl', 'recombin', 'energi', 'also', 'result', 'atom', 'mass', 'fraction', 'realist', 'less', 'equilibrium', 'frozen', 'situat', 'throughout', 'cold', 'wall', 'boundari', 'layer']
# ['design', 'minimum', 'drag', 'tip', 'fin', 'appendix', 'conform', 'transform', 'wing', 'fin', 'report', 'describ', 'investig', 'design', 'minimum', 'drag', 'tip', 'fin', 'lift', 'line', 'theori', 'work', 'base', 'exact', 'solut', 'conform', 'transform', 'applic', 'problem', 'follow', 'method', 'trefitz', 'three', 'type', 'solut', 'treat', 'correspond', 'symmetr', 'upper', 'lower', 'fin', 'singl', 'upper', 'lower', 'fin', 'unequ', 'upper', 'lower', 'fin', 'repres', 'rang', 'solut', 'circul', 'distribut', 'along', 'wing', 'fin', 'calcul', 'three', 'case', 'use', 'ellipt', 'theta', 'function', 'detail', 'account', 'given', 'exampl', 'procedur', 'calcul', 'plan', 'wing', 'fin', 'lift', 'induc', 'drag', 'set', 'fin']
# ['liapunov', 'method', 'automat', 'control', 'theori', 'work', 'liapunov', 'theori', 'stabil', 'discuss', 'second', 'method', 'liapunov', 'shown', 'applic', 'linear', 'equat', 'real', 'constant', 'coeffici', 'proof', 'routhhurwitz', 'criterion', 'linear', 'equat', 'period', 'coeffici', 'practic', 'exampl', 'includ', 'non', 'linear', 'stabil', 'problem', 'control', 'function', 'use', 'area', 'control', 'system']
', 'blade', 'failur', 'attribut', 'reson', 'vibrat', 'excit', 'rotat', 'stall', 'experienc', 'singl', 'multistag', 'compressor', 'stage', 'stack', 'analysi', 'deterior', 'stage', 'perform', 'due', 'unsteadi', 'flow', 'result', 'stall', 'adjac', 'stage', 'consid', 'gener', 'pressur', 'drop', 'stall', 'point', 'believ', 'much', 'larger', 'indic', 'analyt', 'formul', 'compressor', 'perform', 'compressor', 'surg', 'attribut', 'limit', 'cycl', 'oper', 'compressor', 'stall', 'point', 'indic', 'compressor', 'test', 'jet', 'engin', 'test', 'small', 'compressor', 'discharg', 'receiv', 'volum', 'may', 'result', 'simpli', 'stall', 'compressor', 'without', 'cyclic', 'characterist', 'compressor', 'surg', 'event', 'engin', 'oper', 'limit', 'larg', 'drop', 'perform', 'accompani', 'compressor', 'stall']
# ['hyperson', 'wind', 'tunnel', 'farnborough', 'part', 'iii', 'calibr', 'flow', 'work', 'section', 'fuse', 'silica', 'nozzl', 'give', 'hyperson', 'wind', 'tunnel', 'produc', 'flow', 'field', 'averag', 'mach', 'number', 'along', 'centrelin', 'work', 'section', 'mach', 'number', 'gradual', 'decreas', 'toward', 'boundari', 'layer', 'core', 'approxim', 'mach', 'number', 'nozzl', 'heat', 'run', 'littl', 'effect', 'mach', 'number', 'distribut', 'one', 'station', 'mach', 'number', 'one', 'third', 'per', 'cent', 'greater', 'run', 'minut', 'run', 'second', 'temperatur', 'field', 'inviscid', 'flow', 'averag', 'variat', 'temperatur', 'time', 'throughout', 'run']
# ['bend', 'uniformli', 'load', 'rectangular', 'plate', 'two', 'adjac', 'edg', 'either', 'simpli', 'support', 'free', 'distribut', 'deflect', 'bend', 'moment', 'uniformli', 'load', 'rectangular', 'plate', 'two', 'adjac', 'edg', 'clamp', 'either', 'simpli', 'support', 'free', 'obtain', 'method', 'superposit', 'numer', 'valu', 'given', 'squar', 'plate', 'one', 'case', 'result', 'compar', 'obtain', 'anoth', 'method']
# ['properti', 'cross', 'flexur', 'pivot', 'influenc', 'point', 'strip', 'cross', 'shown', 'rotat', 'stiff', 'cross', 'flexur', 'pivot', 'vari', 'consider', 'subject', 'appli', 'forc', 'type', 'variat', 'radic', 'chang', 'simpli', 'move', 'point', 'strip', 'cross', 'relat', 'torqu', 'rotat', 'given', 'appli', 'forc', 'exactli', 'linear', 'extent', 'non', 'linear', 'determin', 'take', 'account', 'small', 'movement', 'centr', 'rotat', 'pivot', 'final', 'design', 'purpos', 'analysi', 'maximum', 'stress', 'strip', 'given']
# ['boundari', 'layer', 'transit', 'inject', 'mass', 'inject', 'process', 'propos', 'method', 'cool', 'aerodynam', 'surfac', 'sinc', 'amount', 'coolant', 'requir', 'maintain', 'practic', 'wall', 'temperatur', 'consider', 'larger', 'turbul', 'laminar', 'boundari', 'layer', 'knowledg', 'effect', 'cool', 'method', 'transit', 'process', 'certainli', 'import', 'exploratori', 'studi', 'report', 'conduct', 'mach', 'number', 'ascertain', 'effect', 'inject', 'stabil', 'laminar', 'boundari', 'layer', 'conic', 'surfac']
# %%
frequency_map = {}
for i in range(no_of_docs):
    tokens = all_docs[i].split()
    for w in tokens:
        try:
            frequency_map[w].add(i)
        except:
            frequency_map[w] = {i}
for i in frequency_map:
    frequency_map[i] = len(frequency_map[i])

# %%
print(frequency_map)
# Out:
# {'similitud': 8, 'hyperson': 106, 'real': 16, 'flow': 430, 'slender': 60, 'bodi': 167, 'blunt': 77, 'nose': 59, 'basi': 36, 'small': 117, 'perturb': 15, 'theori': 224, 'law': 32, 'inviscid': 54, 'field': 107, 'thin': 41, 'examin': 30, 'restrict': 25, 'ideal': 28, 'gase': 24, 'constant': 102, 'specif': 36, 'heat': 184, 'point': 130, 'remov': 4, 'steadi': 48, 'plane': 54, 'axisymmetr': 24, 'consid': 124, 'inspect': 1, 'govern': 27, 'system': 42, 'equat': 200, 'show': 105, 'exist': 61, 'local': 68, 'thermal': 51, 'equilibrium': 36, 'free': 124, 'stream': 130, 'atmospher': 39, 'requir': 74, 'composit': 13, 'pressur': 273, 'densiti': 54, 'replac': 20, 'ratio': 141, 'wedg': 24, 'cone': 52, 'special': 39, 'obtain': 224, 'applic': 117, 'similar': 99, 'rule': 7, 'case': 182, 'flat': 101, 'plate': 121, 'lead': 97, 'edg': 100, 'air': 105, 'possibl': 78, 'simul': 14, 'nonequilibrium': 11, 'also': 153, 'behaviour': 8, 'non': 28, 'linear': 67, 'mani': 19, 'phenomena': 21, 'occur': 55, 'world': 1, 'around': 31, 'nonlinear': 19, 'relationship': 12, 'develop': 129, 'mathemat': 19, 'scienc': 2, 'difficulti': 15, 'analysi': 128, 'hinder': 1, 'formul': 27, 'concept': 30, 'would': 34, 'permit': 20, 'understand': 10, 'present': 231, 'articl': 5, 'progress': 9, 'behavior': 22, 'review': 31, 'attempt': 20, 'made': 171, 'result': 332, 'way': 18, 'may': 113, 'appli': 102, 'gener': 161, 'problem': 162, 'structur': 37, 'aerelast': 1, 'consider': 76, 'high': 129, 'speed': 168, 'flight': 52, 'domin': 6, 'factor': 39, 'design': 60, 'aircraft': 29, 'aeroelast': 10, 'origin': 22, 'subject': 31, 'matter': 2, 'concern': 28, 'larg': 96, 'discuss': 132, 'interrel': 1, 'one': 137, 'anoth': 17, 'summari': 7, 'analyt': 55, 'experiment': 166, 'tool': 6, 'avail': 42, 'aeronaut': 9, 'engin': 15, 'meet': 4, 'demand': 2, 'upon': 31, 'state': 27, 'art': 2, 'respect': 42, 'transfer': 139, 'boundari': 283, 'layer': 265, 'mode': 22, 'failur': 7, 'combin': 54, 'load': 53, 'well': 70, 'input': 8, 'acrothermoelast': 1, 'method': 239, 'attack': 46, 'allevi': 6, 'summar': 9, 'final': 31, 'avenu': 2, 'fundament': 15, 'research': 23, 'suggest': 42, 'comment': 7, 'improv': 31, 'numer': 104, 'solut': 209, 'blasiu': 12, 'three': 68, 'condit': 168, 'attent': 20, 'drawn': 5, 'previou': 24, 'accur': 43, 'vapour': 1, 'screen': 3, 'visual': 7, 'tunnel': 89, 'rae': 6, 'bedford': 2, 'visualis': 2, 'superson': 144, 'wind': 70, 'outlin': 9, 'suitabl': 24, 'techniqu': 55, 'use': 259, 'describ': 75, 'togeth': 18, 'associ': 32, 'optic': 9, 'photograph': 12, 'equip': 4, 'test': 98, 'determin': 134, 'humid': 3, 'produc': 42, 'optimum': 13, 'fog': 1, 'work': 64, 'section': 72, 'mach': 193, 'number': 300, 'rang': 135, 'temperatur': 154, 'behind': 37, 'delta': 16, 'wing': 105, 'includ': 98, 'comparison': 65, 'correspond': 57, 'surfac': 177, 'oil': 5, 'pattern': 26, 'process': 34, 'condens': 2, 'physic': 39, 'properti': 63, 'format': 6, 'pictur': 8, 'detail': 54, 'effect': 282, 'static': 32, 'investig': 168, 'compar': 132, 'theoret': 121, 'estim': 51, 'nomin': 10, 'shown': 150, 'advers': 12, 'liquid': 14, 'lower': 41, 'latent': 1, 'evapor': 2, 'water': 8, 'extend': 48, 'transon': 31, 'subson': 57, 'laminar': 145, 'shock': 126, 'advanc': 9, 'stationari': 20, 'fluid': 101, 'studi': 122, 'compress': 82, 'induc': 37, 'wave': 109, 'bound': 4, 'wall': 105, 'weak': 13, 'ident': 8, 'infinit': 48, 'impuls': 4, 'set': 37, 'uniform': 45, 'motion': 72, 'veloc': 188, 'profil': 75, 'recoveri': 17, 'skinfrict': 3, 'coeffici': 118, 'tabul': 14, 'wide': 27, 'strength': 23, 'revolut': 42, 'chemic': 22, 'locat': 35, 'move': 33, 'given': 207, 'provid': 68, 'mean': 78, 'comput': 61, 'characterist': 85, 'take': 35, 'place': 17, 'assum': 80, 'within': 64, 'thermochem': 3, 'must': 23, 'known': 41, 'essenti': 30, 'new': 37, 'featur': 30, 'solv': 33, 'direct': 61, 'initi': 37, 'data': 96, 'upstream': 20, 'shape': 108, 'integr': 81, 'done': 7, 'inher': 2, 'less': 42, 'avoid': 13, 'interpret': 19, 'accord': 17, 'definit': 9, 'not ...

# %%
frequency_map
# Out:
# {'similitud': 8,
#  'hyperson': 106,
#  'real': 16,
#  'flow': 430,
#  'slender': 60,
#  'bodi': 167,
#  'blunt': 77,
#  'nose': 59,
#  'basi': 36,
#  'small': 117,
#  'perturb': 15,
#  'theori': 224,
#  'law': 32,
#  'inviscid': 54,
#  'field': 107,
#  'thin': 41,
#  'examin': 30,
#  'restrict': 25,
#  'ideal': 28,
#  'gase': 24,
#  'constant': 102,
#  'specif': 36,
#  'heat': 184,
#  'point': 130,
#  'remov': 4,
#  'steadi': 48,
#  'plane': 54,
#  'axisymmetr': 24,
#  'consid': 124,
#  'inspect': 1,
#  'govern': 27,
#  'system': 42,
#  'equat': 200,
#  'show': 105,
#  'exist': 61,
#  'local': 68,
#  'thermal': 51,
#  'equilibrium': 36,
#  'free': 124,
#  'stream': 130,
#  'atmospher': 39,
#  'requir': 74,
#  'composit': 13,
#  'pressur': 273,
#  'densiti': 54,
#  'replac': 20,
#  'ratio': 141,
#  'wedg': 24,
#  'cone': 52,
#  'special': 39,
#  'obtain': 224,
#  'applic': 117,
#  'similar': 99,
#  'rule': 7,
#  'case': 182,
#  'flat': 101,
#  'plate': 121,
#  'lead': 97,
#  'edg': 100,
#  'air': 105,
#  'possibl': 78,
#  'simul': 14,
#  'nonequilibrium': 11,
#  'also': 153,
#  'behaviour': 8,
#  'non': 28,
#  'linear': 67,
#  'mani': 19,
#  'phenomena': 21,
#  'occur': 55,
#  'world': 1,
#  'around': 31,
#  'nonlinear': 19,
#  'relationship': 12,
#  'develop': 129,
#  'mathemat': 19,
#  'scienc': 2,
#  'difficulti': 15,
#  'analysi': 128,
#  'hinder': 1,
#  'formul': 27,
#  'concept': 30,
#  'would': 34,
#  'permit': 20,
#  'understand': 10,
#  'present': 231,
#  'articl': 5,
#  'progress': 9,
#  'behavior': 22,
#  'review': 31,
#  'attempt': 20,
#  'made': 171,
#  'result': 332,
#  'way': 18,
#  'may': 113,
#  'appli': 102,
#  'gener': 161,
#  'problem': 162,
#  'structur': 37,
#  'aerelast': 1,
#  'consider': 76,
#  'high': 129,
#  'speed': 168,
#  'flight': 52,
#  'domin': 6,
#  'factor': 39,
#  'design': 60,
#  'aircraft': 29,
#  'aeroelast': 10,
#  'origin': 22,
#  'subject': 31,
#  'matter': 2,
#  'concern': 28,
#  'larg': 96,
#  'discuss': 132,
#  'interrel': 1,
#  'one': 137,
#  'anoth': 17,
#  'summari': 7,
#  'analyt': 55,
#  'experiment': 166,
#  'tool': 6,
#  'avail': 42,
#  'aeronaut': 9,
#  'engin': 15,
#  'meet': 4,
#  'demand': 2,
#  'upon': 31,
#  'state': 27,
#  'art': 2,
#  'respect': 42,
#  'transfer': 139,
#  'boundari': 283,
#  'layer': 265,
#  'mode': 22,
#  'failur': 7,
#  'combin': 54,
#  'load': 53,
#  'well': 70,
#  'input': 8,
#  'acrothermoelast': 1,
#  'method': 239,
#  'attack': 46,
#  'allevi': 6,
#  'summar': 9,
#  'final': 31,
#  'avenu': 2,
#  'fundament': 15,
#  'research': 23,
#  'suggest': 42,
#  'comment': 7,
#  'improv': 31,
#  'numer': 104,
#  'solut': 209,
#  'blasiu': 12,
#  'three': 68,
#  'condit': 168,
#  'attent': 20,
#  'drawn': 5,
#  'previou': 24,
#  'accur': 43,
#  'vapour': 1,
#  'screen': 3,
#  'visual': 7,
#  'tunnel': 89,
#  'rae': 6,
#  'bedford': 2,
#  'visualis': 2,
#  'superson': 144,
#  'wind': 70,
#  'outlin': 9,
#  'suitabl': 24,
#  'techniqu': 55,
#  'use': 259,
#  'describ': 75,
#  'togeth': 18,
#  'associ': 32,
#  'optic': 9,
#  'photograph': 12,
#  'equip': 4,
#  'test': 98,
#  'determin': 134,
#  'humid': 3,
#  'produc': 42,
#  'optimum': 13,
#  'fog': 1,
#  'work': 64,
#  'section': 72,
#  'mach': 193,
#  'number': 300,
#  'rang': 135,
#  'temperatur': 154,
#  'behind': 37,
#  'delta': 16,
#  'wing': 105,
#  'includ': 98,
#  'comparison': 65,
#  'correspond': 57,
#  'surfac': 177,
#  'oil': 5,
#  'pattern': 26,
#  'process': 34,
#  'condens': 2,
#  'physic': 39,
#  'properti': 63,
#  'format': 6,
#  'pictur': 8,
#  'detail': 54,
#  'effect': 282,
#  'static': 32,
#  'investig': 168,
#  'compar': 132,
#  'theoret': 121,
#  'estim': 51,
#  'nomin': 10,
#  'shown': 150,
#  'advers': 12,
#  'liquid': 14,
#  'lower': 41,
#  'latent': 1,
#  'evapor': 2,
#  'water': 8,
#  'extend': 48,
#  'transon': 31,
#  'subson': 57,
#  'laminar': 145,
#  'shock': 126,
#  'advanc': 9,
#  'stationari': 20,
#  'fluid': 101,
#  'studi': 122,
#  'compress': 82,
#  'induc': 37,
#  'wave': 109,
#  'bound': 4,
#  'wall': 105,
#  'weak': 13,
#  'ident': 8,
#  'infinit': 48,
#  'impuls': 4,
#  'set': 37,
#  'uniform': 45,
#  'motion': 72,
#  'veloc': 188,
#  'profil': 75,
#  'recoveri': 17,
#  'skinfrict': 3,
#  'coeffici': 118,
#  'tabul': 14,
#  'wide': 27,
#  'strength': 23,
#  'revolut': 42,
#  'chemic': 22,
#  'locat': 35,
#  'move': 33,
#  'given': 207,
#  'provid': 68,
#  'mean': 78,
#  'comput': 61,
#  'characterist': 85,
#  'take': 35,
#  'place': 17,
#  'assum': 80,
#  'within': 64,
#  'thermochem': 3,
#  'must': 23,
#  'known': 41,
#  'essenti': 30,
#  'new': 37,
#  'featur': 30,
#  'solv': 33,
#  'direct': 61,
#  'initi': 37,
#  'data': 96,
#  'upstream': 20,
#  'shape': 108,
#  'integr': 81,
#  'done': 7,
#  'inher': 2,
#  'less': 42,
#  'avoid': 13,
#  'interpret': 19,
#  'accord': 17,
#  'definit': 9,
#  'note': 70,
#  'transit': 54,
#  'refer': 41,
#  'shroud': 4,
#  'predict': 100,
#  'base': 112,
#  'persh': 1,
#  'agreement': 85,
#  'experi': 73,
#  'region': 97,
#  'found': 163,
#  'qualit': 22,
#  'good': 69,
#  'quantit': 10,
#  'fair': 10,
#  'purpos': 42,
#  'addit': 52,
#  'convent': 19,
#  'indic': 89,
#  'somewhat': 14,
#  'viscou': 79,
#  'along': 66,
#  'distort': 5,
#  'coordin': 20,
#  'past': 52,
#  'simpl': 102,
#  'give': 79,
#  'complet': 52,
#  'represent': 9,
#  'consist': 32,
#  'first': 85,
#  'order': 95,
#  'express': 71,
#  'correct': 37,
#  'second': 56,
#  'import': 63,
#  'paramet': 86,
#  'satisfi': 21,
#  'arbitrari': 45,
#  'reynold': 111,
#  'differ': 97,
#  'curv': 44,
#  'correl': 45,
#  'close': 47,
#  'asymptot': 21,
#  'skin': 60,
#  'friction': 62,
#  'deduc': 14,
#  'verif': 5,
#  'yet': 11,
#  'self': 11,
#  'sustain': 2,
#  'oscil': 21,
#  'damp': 17,
#  'particular': 54,
#  'type': 84,
#  'paper': 89,
#  'deal': 18,
#  'dynam': 27,
#  'singl': 29,
#  'degre': 31,
#  'freedom': 11,
#  'restor': 1,
#  'forc': 68,
#  'latter': 25,
#  'suppos': 6,
#  'function': 88,
#  'polygon': 5,
#  'graph': 5,
#  'neg': 13,
#  'becom': 30,
#  'posit': 46,
#  'certain': 54,
#  'valu': 160,
#  'assumpt': 68,
#  'rigor': 4,
#  'amplitud': 9,
#  'maximum': 40,
#  'period': 17,
#  'limit': 67,
#  'vanishingli': 1,
#  'approxim': 190,
#  'seri': 35,
#  'power': 42,
#  'satisfactori': 23,
#  'accuraci': 36,
#  'quit': 15,
#  'sharp': 30,
#  'zero': 83,
#  'lift': 73,
#  'sever': 54,
#  'planform': 9,
#  'diamond': 2,
#  'cross': 30,
#  'intend': 8,
#  'separ': 88,
#  'distribut': 197,
#  'overal': 16,
#  'normalpressur': 1,
#  'drag': 76,
#  'variou': 75,
#  'achiev': 17,
#  'calcul': 161,
#  'presenc': 33,
#  'respons': 7,
#  'decay': 10,
#  'convect': 31,
#  'randon': 1,
#  'follow': 46,
#  'lyon': 1,
#  'vibratori': 3,
#  'random': 6,
#  'scale': 25,
#  'size': 15,
#  'exponenti': 6,
#  'two': 192,
#  'much': 29,
#  'flexur': 4,
#  'squar': 24,
#  'displac': 27,
#  'rel': 49,
#  'independ': 34,
#  'increas': 97,
#  'significantli': 6,
#  'usual': 34,
#  'alway': 14,
#  'vibrat': 19,
#  'reduct': 22,
#  'smaller': 9,
#  'hysteret': 1,
#  'yaw': 20,
#  'circular': 37,
#  'cylind': 53,
#  'measur': 128,
#  'reduc': 58,
#  'averag': 25,
#  'front': 14,
#  'side': 13,
#  'exampl': 63,
#  'percent': 25,
#  'amount': 23,
#  'herein': 12,
#  'littl': 12,
#  'dropoff': 1,
#  'due': 72,
#  'flutter': 24,
#  'dimension': 119,
#  'oscillatori': 8,
#  'van': 6,
#  'dyke': 4,
#  'piston': 9,
#  'landahl': 2,
#  'tangentwedg': 1,
#  'tangent': 10,
#  'newtonian': 23,
#  'higher': 53,
#  'illustr': 35,
#  'aris': 22,
#  'thick': 104,
#  'depend': 61,
#  'frequenc': 19,
#  'influenc': 60,
#  'airfoil': 42,
#  'trend': 10,
#  'center': 12,
#  'graviti': 8,
#  'elast': 14,
#  'axi': 25,
#  'refin': 10,
#  'stabil': 35,
#  'gradient': 69,
#  'minimum': 13,
#  'critic': 26,
#  'prandtl': 46,
#  'uniti': 24,
#  'viscos': 44,
#  'proport': 20,
#  'sutherland': 3,
#  'relat': 83,
#  'throughout': 13,
#  'mass': 48,
#  'cool': 44,
#  'laminari': 1,
#  'inject': 27,
#  'light': 17,
#  'weight': 13,
#  'foreign': 6,
#  'concentr': 17,
#  'dissip': 14,
#  'porou': 22,
#  'hydrogen': 3,
#  'admixtur': 1,
#  'low': 87,
#  'capac': 6,
#  'greatli': 14,
#  'diminish': 7,
#  'markedli': 5,
#  'reliev': 1,
#  'intens': 17,
#  'aerodynam': 83,
#  'photo': 4,
#  'thermoelast': 5,
#  'transient': 19,
#  'stress': 40,
#  'multiweb': 1,
#  'photothermoelast': 4,
#  'perform': 39,
#  'long': 22,
#  'model': 84,
#  'literatur': 8,
#  'procedur': 39,
#  'util': 20,
#  'prescrib': 14,
#  'fulli': 20,
#  'term': 79,
#  'dimensionless': 13,
#  'time': 65,
#  'biot': 4,
#  'reveal': 7,
#  'observ': 52,
#  'web': 4,
#  'flang': 3,
#  'major': 20,
#  'sourc': 19,
#  'discrep': 8,
#  'trace': 3,
#  'conduct': 94,
#  'employ': 33,
#  'farnborough': 3,
#  'part': 63,
#  'instrument': 7,
#  'calibr': 9,
#  'report': 54,
#  'lay': 1,
#  'plant': 4,
#  'figur': 9,
#  'compon': 32,
#  'facil': 5,
#  'briefli': 16,
#  'later': 19,
#  'workingsect': 1,
#  'heater': 2,
#  'start': 15,
#  'run': 8,
#  'blockag': 5,
#  'electr': 28,
#  'parallel': 40,
#  'magnet': 29,
#  'space': 15,
#  'formula': 45,
#  'histori': 12,
#  'rather': 19,
#  'tediou': 3,
#  'fact': 20,
#  'handicap': 1,
#  'optim': 3,
#  'project': 4,
#  'stage': 19,
#  'desir': 17,
#  'abl': 4,
#  'manner': 26,
#  'deriv': 108,
#  'typic': 18,
#  'placehold': 1,
#  'quasi': 11,
#  'incompress': 86,
#  'bend': 15,
#  'torsion': 8,
#  'explicit': 6,
#  'theodorsen': 1,
#  'equal': 22,
#  'diagon': 1,
#  'virtual': 4,
#  'neglig': 19,
#  'earlier': 13,
#  'empir': 24,
#  'garrick': 1,
#  'nonsteadi': 4,
#  'emphas': 12,
#  'variabl': 41,
#  'recombin': 7,
#  'stagnat': 72,
#  'atom': 12,
#  'extern': 35,
#  'decreas': 39,
#  'allow': 22,
#  'energi': 51,
#  'fraction': 11,
#  'realist': 3,
#  'frozen': 6,
#  'situat': 14,
#  'cold': 6,
#  'tip': 11,
#  'fin': 8,
#  'appendix': 9,
#  'conform': 4,
#  'transform': 37,
#  'line': 34,
#  'exact': 72,
#  'trefitz': 1,
#  'treat': 45,
#  'symmetr': 48,
#  'upper': 23,
#  'unequ': 1,
#  'repres': 52,
#  'circul': 7,
#  'ellipt': 14,
#  'theta': 1,
#  'account': 50,
#  'plan': 11,
#  'liapunov': 1,
#  'automat': 5,
#  'control': 31,
#  'proof': 3,
#  'routhhurwitz': 1,
#  'criterion': 10,
#  'practic': 57,
#  'area': 23,
#  'taylor': 13,
#  'instabl': 9,
#  'finit': 35,
#  'acceler': 16,
#  'interfac': 7,
#  'methanol': 1,
#  'carbon': 3,
#  'tetrachlorid': 1,
#  'sinusoid': 5,
#  'disturb': 37,
#  'cut': 3,
#  'growth': 10,
#  'rate': 84,
#  'third': 10,
#  'overst': 1,
#  'agre': 29,
#  'moder': 20,
#  'disclos': 1,
#  'bubbl': 2,
#  'competit': 1,
#  'helmholtz': 2,
#  'turbul': 92,
#  'jet': 39,
#  'product': 12,
#  'drop': 5,
#  'nois': 12,
#  'hot': 14,
#  'wire': 13,
#  'fluctuat': 15,
#  'rapidli': 16,
#  'sound': 22,
#  'dash': 6,
#  'dashth': 1,
#  'furthermor': 8,
#  'orient': 5,
#  'soundsourc': 1,
#  'half': 20,
#  'nozzl': 39,
#  'form': 115,
#  'vehicl': 23,
#  'enter': 12,
#  'planetari': 5,
#  'author': 46,
#  'missil': 19,
#  'customari': 2,
#  'distanc': 61,
#  'travel': 6,
#  'constanc': 1,
#  'absenc': 2,
#  'spin': 3,
#  'could': 29,
#  'add': 3,
#  'common': 8,
#  'ballist': 8,
#  'condamp': 1,
#  'slow': 7,
#  'variat': 76,
#  'coefstant': 1,
#  'simpli': 8,
#  'exponentiallyfici': 1,
#  'spoken': 1,
#  'wkb': 2,
#  'howev': 51,
#  'appar': 16,
#  'greater': 38,
#  'essenc': 2,
#  'explicitli': 4,
#  'brief': 14,
#  'commun': 1,
#  'confluent': 2,
#  'hypergeometr': 3,
#  'defin': 28,
#  'involv': 54,
#  'gamma': 1,
#  'laguerr': 1,
#  'polynomi': 9,
#  'bessel': 2,
#  'certainli': 2,
#  'nice': 1,
#  'heretofor': 2,
#  'extens': 33,
#  'approach': 48,
#  'puzzl': 1,
#  'signific': 38,
#  'propos': 25,
#  'facilit': 3,
#  'necess': 2,
#  'difficult': 11,
#  'revers': 12,
#  'evalu': 36,
#  'compet': 1,
#  'view': 13,
#  'afresh': 1,
#  'without': 37,
#  'constraint': 6,
#  'impos': 11,
#  'prior': 3,
#  'seem': 10,
#  'least': 16,
#  'easi': 2,
#  'standard': 13,
#  'vertic': 18,
#  'act': 14,
#  'perpendicular': 10,
#  'vari': 68,
#  'invers': 11,
#  'fourth': 7,
#  'root': 10,
#  'lowest': 4,
#  'end': 13,
#  'nusselt': 5,
#  'hydromagnet': 2,
#  'hyperbol': 5,
#  'momentum': 36,
#  'put': 6,
#  'yield': 32,
#  'establish': 22,
#  'normal': 48,
#  'magnetohydrodynam': 17,
#  'vector': 5,
#  'thu': 38,
#  'chang': 62,
#  'class': 17,
#  'five': 7,
#  'thought': 3,
#  'especi': 16,
#  'conveni': 6,
#  'downstream': 36,
#  'quantiti': 23,
#  'alfven': 2,
#  'falkner': 6,
#  'skan': 6,
#  'treatment': 24,
#  'differenti': 42,
#  'analys': 20,
#  'see': 7,
#  'abstract': 2,
#  'iter': 8,
#  'machin': 9,
#  'insuffici': 1,
#  'specifi': 10,
#  'uniqu': 6,
#  'appropri': 16,
#  'whose': 20,
#  'break': 7,
#  'away': 5,
#  'helium': 25,
#  'twopoint': 1,
#  'mix': 33,
#  'inner': 8,
#  'shear': 54,
#  'outer': 26,
#  'adjust': 8,
#  'freestream': 7,
#  'suffici': 27,
#  'eigenvalu': 2,
#  'varieti': 10,
#  'roll': 18,
#  'trail': 27,
#  'vortex': 24,
#  'sheet': 7,
#  'downwash': 9,
#  'vortic': 37,
#  'proper': 6,
#  'span': 21,
#  'aspect': 35,
#  'aspectratio': 1,
#  'core': 11,
#  'chord': 18,
#  'length': 38,
#  'intermedi': 12,
#  'partial': 13,
#  'tail': 10,
#  'interact': 59,
#  'charg': 9,
#  'satellit': 20,
#  'ionospher': 5,
#  'ion': 4,
#  'infinitesim': 6,
#  'object': 15,
#  'simplifi': 24,
#  'sampl': 6,
#  'spheric': 19,
#  'charact': 10,
#  'wake': 28,
#  'socal': 1,
#  'previous': 22,
#  'jastrow': 2,
#  'pears': 2,
#  'diverg': 17,
#  'chordwis': 12,
#  'spanwis': 11,
#  'twist': 5,
#  'taken': 32,
#  'success': 23,
#  'phase': 7,
#  'complex': 12,
#  'curl': 1,
#  'cantilev': 11,
#  'strong': 25,
#  'poisson': 1,
#  'magnitud': 31,
#  'deform': 4,
#  'mechan': 16,
#  'nearli': 19,
#  'propel': 11,
#  'realiz': 6,
#  'earli': 10,
#  'like': 12,
#  'harri': 1,
#  'torqu': 3,
#  'unyaw': 6,
#  'directli': 17,
#  'blade': 15,
#  'none': 2,
#  'incorpor': 6,
#  'induct': 5,
#  'adequ': 15,
#  'cover': 19,
#  'oper': 26,
#  'analog': 39,
#  'roughli': 3,
#  'disk': 4,
#  'augment': 2,
#  'inflow': 1,
#  'fixedpitch': 1,
#  'diamet': 31,
#  'angular': 2,
#  'pitch': 22,
#  'analyz': 27,
#  'actual': 21,
#  'maneuv': 5,
#  'except': 39,
#  'conclus': 29,
#  'dual': 1,
#  'rotat': 28,
#  'moment': 36,
#  'lever': 1,
#  'arm': 2,
#  'radiu': 21,
#  'coupl': 14,
#  'chart': 10,
#  'therefrom': 1,
#  'sonic': 23,
#  'near': 58,
#  'domain': 3,
#  'reflect': 23,
#  'slope': 19,
#  'geometri': 23,
#  'uncamb': 3,
#  'superimpos': 1,
#  'equival': 17,
#  'scheme': 4,
#  'angl': 93,
#  'conjunct': 11,
#  'tabl': 21,
#  'entropi': 6,
#  'windward': 1,
#  'meridian': 2,
#  'tend': 19,
#  'recent': 47,
#  'controversi': 2,
#  'glauert': 5,
#  'natur': 20,
#  'worthwhil': 1,
#  'draw': 3,
#  'navier': 10,
#  'stoke': 11,
#  'lend': 3,
#  'support': 26,
#  'transpir': 9,
#  'rubesin': 6,
#  'film': 5,
#  'either': 34,
#  'coolant': 13,
#  'uncool': 4,
#  'stack': 4,
#  'compressor': 16,
#  'map': 7,
#  'multi': 2,
#  'axial': 50,
#  'knowledg': 13,
#  'individu': 4,
#  'alter': 11,
#  'find': 16,
#  'sublay': 7,
#  'introduc': 42,
#  'grow': 4,
#  'hypothesi': 3,
#  'substanti': 15,
#  'particularli': 10,
#  'contain': 18,
#  'stall': 9,
#  'surg': 3,
#  'anemomet': 6,
#  'multistag': 3,
#  'portion': 23,
#  'instig': 1,
#  'almost': 16,
#  'simultan': 19,
#  'attribut': 11,
#  'reson': 3,
#  'excit': 10,
#  'experienc': 3,
#  'deterior': 3,
#  'unsteadi': 16,
#  'adjac': 15,
#  'believ': 7,
#  'larger': 21,
#  'cycl': 4,
#  'discharg': 4,
#  'receiv': 7,
#  'volum': 11,
#  'cyclic': 1,
#  'event': 2,
#  'accompani': 9,
#  'iii': 4,
#  'fuse': 1,
#  'silica': 1,
#  'centrelin': 1,
#  'gradual': 4,
#  'toward': 11,
#  'station': 11,
#  'per': 39,
#  'cent': 22,
#  'minut': 6,
#  'uniformli': 10,
#  'rectangular': 18,
#  'deflect': 27,
#  'clamp': 10,
#  'superposit': 1,
#  'pivot': 2,
#  'strip': 7,
#  'stiff': 7,
#  'radic': 2,
#  'exactli': 9,
#  'extent': 12,
#  'movement': 6,
#  'centr': 9,
#  'sinc': 30,
#  'maintain': 11,
#  'exploratori': 4,
#  'ascertain': 2,
#  'conic': 32,
#  'expans': 40,
#  'maccol': 4,
#  'ogiv': 10,
#  'modifi': 31,
#  'fine': 11,
#  'appreci': 22,
#  'cannot': 12,
#  'although': 36,
#  'highest': 4,
#  'hyperveloc': 6,
#  'unpow': 1,
#  'propuls': 7,
#  'day': 5,
#  'rocket': 12,
#  'motor': 2,
#  'character': 11,
#  'return': 4,
#  'earth': 14,
#  'skip': 2,
#  'glide': 2,
#  'trajectori': 6,
#  'senior': 1,
#  'naca': 12,
#  'radiant': 1,
#  'connect': 16,
#  'effici': 12,
#  'sens': 5,
#  'attain': 5,
#  'disadvantag': 2,
#  'offset': 1,
#  'entri': 15,
#  'artific': 2,
#  'kinet': 11,
#  'minim': 7,
#  'materi': 18,
#  'neighborhood': 4,
#  'far': 23,
#  'superior': 2,
#  'abil': 2,
#  'convert': 3,
#  'compens': 1,
#  'advantag': 11,
#  'main': 29,
#  'radiat': 20,
#  'back': 8,
#  'consequ': 13,
#  'kept': 3,
#  'cylindr': 22,
#  'lie': 12,
#  'camber': 12,
#  'circularcylindr': 2,
#  'ring': 4,
#  'travers': 9,
#  'postul': 5,
#  ...}

# %%
N=690
term_matrix = {}
# print(N)
for key in sorted(frequency_map):
    x=(N - frequency_map[key] + 0.5)/(frequency_map[key] + 0.5)
    term_matrix[key] = math.log(x, 2) 
    
term_matrix
# Out:
# {'abbrevi': 8.844444240792825,
#  'abil': 8.105384749247602,
#  'abl': 7.253190908704789,
#  'ablat': 7.253190908704789,
#  'abovement': 8.844444240792825,
#  'abrupt': 8.105384749247602,
#  'abruptli': 8.105384749247602,
#  'absenc': 8.105384749247602,
#  'absent': 8.844444240792825,
#  'absolut': 6.961581237141928,
#  'absorb': 7.253190908704789,
#  'absorpt': 7.617860981241781,
#  'abstract': 8.105384749247602,
#  'academ': 8.844444240792825,
#  'acceler': 5.353280513589814,
#  'accept': 6.961581237141928,
#  'accommod': 8.105384749247602,
#  'accompani': 6.164642333361623,
#  'accomplish': 6.509906931997541,
#  'accord': 5.266251118517337,
#  'accordingli': 6.961581237141928,
#  'account': 3.664843277589852,
#  'accru': 8.844444240792825,
#  'accumul': 8.844444240792825,
#  'accur': 3.8957928867251885,
#  'accuraci': 4.164424823065223,
#  'achiev': 5.266251118517337,
#  'ackeret': 7.617860981241781,
#  'acoust': 6.718467013116808,
#  'acquir': 8.844444240792825,
#  'acr': 8.844444240792825,
#  'across': 4.648204934712976,
#  'acrothermoelast': 8.844444240792825,
#  'act': 5.543965128848965,
#  'action': 7.253190908704789,
#  'activ': 7.253190908704789,
#  'actual': 4.960675490622213,
#  'actur': 8.844444240792825,
#  'adapt': 8.105384749247602,
#  'add': 7.617860981241781,
#  'addit': 3.604297292036601,
#  'adequ': 5.4456156489388094,
#  'adequaci': 8.105384749247602,
#  'adiabat': 5.543965128848965,
#  'adjac': 5.4456156489388094,
#  'adjoin': 8.844444240792825,
#  'adjoint': 8.844444240792825,
#  'adjust': 6.327222394556876,
#  'admit': 8.105384749247602,
#  'admixtur': 8.844444240792825,
#  'adopt': 7.617860981241781,
#  'adsorpt': 8.844444240792825,
#  'advanc': 6.164642333361623,
#  'advantag': 5.8847677847103785,
#  'advent': 8.844444240792825,
#  'advers': 5.762348815644129,
#  'advisori': 8.844444240792825,
#  'advoc': 8.105384749247602,
#  'aerelast': 8.844444240792825,
#  'aerial': 8.844444240792825,
#  'aero': 8.105384749247602,
#  'aeroballist': 8.844444240792825,
#  'aerodynam': 2.863036306019091,
#  'aerodynamich': 8.844444240792825,
#  'aerodynamieist': 8.844444240792825,
#  'aeroelast': 6.018133928725235,
#  'aeroelastician': 8.844444240792825,
#  'aerofoil': 5.105841370565194,
#  'aeronaut': 6.164642333361623,
#  'aeroplan': 8.105384749247602,
#  'aerothermochem': 8.844444240792825,
#  'aerothermoelast': 8.844444240792825,
#  'affect': 4.765751220973765,
#  'affin': 8.105384749247602,
#  'affirm': 8.844444240792825,
#  'afford': 8.844444240792825,
#  'aforement': 8.844444240792825,
#  'afresh': 8.844444240792825,
#  'aft': 7.617860981241781,
#  'afterbodi': 5.353280513589814,
#  'afterburn': 8.105384749247602,
#  'afterflow': 8.844444240792825,
#  'ago': 8.844444240792825,
#  'agre': 4.486954296916836,
#  'agreement': 2.824130634808431,
#  'ahead': 6.327222394556876,
#  'aid': 6.327222394556876,
#  'ailcron': 8.844444240792825,
#  'aileron': 7.253190908704789,
#  'aim': 6.961581237141928,
#  'air': 2.47242617179403,
#  'airborn': 8.844444240792825,
#  'aircraft': 4.486954296916836,
#  'airflow': 6.961581237141928,
#  'airfoil': 3.9315718281139977,
#  'airload': 8.844444240792825,
#  'airplan': 6.327222394556876,
#  'airscrew': 8.844444240792825,
#  'airspe': 8.105384749247602,
#  'airstream': 7.253190908704789,
#  'alfven': 8.105384749247602,
#  'algebra': 6.961581237141928,
#  'align': 8.844444240792825,
#  'allen': 8.844444240792825,
#  'allevi': 6.718467013116808,
#  'allow': 4.892930653763678,
#  'allround': 8.844444240792825,
#  'almost': 5.353280513589814,
#  'alon': 6.018133928725235,
#  'along': 3.231275326106768,
#  'alreadi': 8.105384749247602,
#  'also': 1.808026099106643,
#  'alter': 5.8847677847103785,
#  'altern': 6.327222394556876,
#  'although': 4.164424823065223,
#  'altitud': 5.266251118517337,
#  'alway': 5.543965128848965,
#  'ambient': 5.8847677847103785,
#  'ame': 8.844444240792825,
#  'amen': 7.253190908704789,
#  'american': 8.844444240792825,
#  'among': 7.617860981241781,
#  'amongst': 8.844444240792825,
#  'amount': 4.828035174897279,
#  'ampli': 8.844444240792825,
#  'amplifi': 8.844444240792825,
#  'amplitud': 6.164642333361623,
#  'amr': 6.961581237141928,
#  'analog': 4.043840620391032,
#  'analogu': 7.617860981241781,
#  'analys': 5.03154151728639,
#  'analysi': 2.1300847369105216,
#  'analyt': 3.517332448654853,
#  'analytici': 8.844444240792825,
#  'analyz': 4.592592941845535,
#  'anemomet': 6.718467013116808,
#  'angl': 2.6759004429804745,
#  'angular': 8.105384749247602,
#  'angularli': 8.844444240792825,
#  'anh': 8.844444240792825,
#  'anhedr': 8.844444240792825,
#  'anisotrop': 8.105384749247602,
#  'anisotropi': 8.844444240792825,
#  'annex': 8.844444240792825,
#  'announc': 8.844444240792825,
#  'annual': 8.844444240792825,
#  'annular': 7.253190908704789,
#  'annulu': 8.105384749247602,
#  'anomal': 8.844444240792825,
#  'anomali': 8.105384749247602,
#  'anoth': 5.266251118517337,
#  'answer': 8.105384749247602,
#  'anti': 8.844444240792825,
#  'antielast': 8.844444240792825,
#  'antisymmetr': 8.105384749247602,
#  'anyway': 8.844444240792825,
#  'apart': 8.844444240792825,
#  'apex': 7.617860981241781,
#  'apoge': 8.844444240792825,
#  'appar': 5.353280513589814,
#  'apparatu': 6.327222394556876,
#  'appear': 3.9315718281139977,
#  'appendic': 8.105384749247602,
#  'appendix': 6.164642333361623,
#  'appl': 8.844444240792825,
#  'appli': 2.5214185055329983,
#  'applic': 2.2871327294508252,
#  'apprais': 8.105384749247602,
#  'appraoch': 8.844444240792825,
#  'appreci': 4.892930653763678,
#  'approach': 3.727639801894113,
#  'appropri': 5.353280513589814,
#  'approx': 8.844444240792825,
#  'approxim': 1.3935790713426714,
#  'arbitrari': 3.8264786451084944,
#  'arbitrarili': 6.961581237141928,
#  'arc': 6.718467013116808,
#  'area': 4.828035174897279,
#  'argon': 6.961581237141928,
#  'argu': 7.617860981241781,
#  'aris': 4.892930653763678,
#  'arisen': 8.844444240792825,
#  'arithmet': 8.844444240792825,
#  'arm': 8.105384749247602,
#  'around': 4.387948925751628,
#  'arrang': 6.961581237141928,
#  'arrest': 8.844444240792825,
#  'arriv': 8.105384749247602,
#  'art': 8.105384749247602,
#  'articl': 6.961581237141928,
#  'artific': 8.105384749247602,
#  'artifici': 6.509906931997541,
#  'ascend': 7.617860981241781,
#  'ascertain': 8.105384749247602,
#  'asimplifi': 8.844444240792825,
#  'ask': 8.844444240792825,
#  'aspect': 4.206704850717073,
#  'aspectratio': 8.844444240792825,
#  'assembl': 8.844444240792825,
#  'assert': 8.844444240792825,
#  'assess': 6.961581237141928,
#  'assign': 8.844444240792825,
#  'assist': 8.844444240792825,
#  'associ': 4.34067181722806,
#  'assort': 8.844444240792825,
#  'assum': 2.9229306068727867,
#  'assumpt': 3.183897943994917,
#  'astronaut': 8.844444240792825,
#  'asymmetr': 7.617860981241781,
#  'asymmetri': 8.844444240792825,
#  'asymptot': 4.960675490622213,
#  'atm': 8.844444240792825,
#  'atmospher': 4.043840620391032,
#  'atom': 5.762348815644129,
#  'atospher': 8.844444240792825,
#  'attach': 4.960675490622213,
#  'attack': 3.7928777372536193,
#  'attain': 6.961581237141928,
#  'attempt': 5.03154151728639,
#  'attend': 7.617860981241781,
#  'attent': 5.03154151728639,
#  'attenu': 7.617860981241781,
#  'attitud': 8.844444240792825,
#  'attract': 8.105384749247602,
#  'attribut': 5.8847677847103785,
#  'augment': 8.105384749247602,
#  'august': 8.844444240792825,
#  'author': 3.7928777372536193,
#  'autocorrel': 8.105384749247602,
#  'automat': 6.961581237141928,
#  'avail': 3.9315718281139977,
#  'avalu': 8.844444240792825,
#  'avenu': 8.105384749247602,
#  'averag': 4.705869513940396,
#  'avoid': 5.649189634077765,
#  'away': 6.961581237141928,
#  'axe': 6.961581237141928,
#  'axi': 4.705869513940396,
#  'axial': 3.664843277589852,
#  'axiallysymmetr': 8.844444240792825,
#  'axisymmetr': 4.765751220973765,
#  'azimuth': 8.844444240792825,
#  'back': 6.327222394556876,
#  'background': 8.105384749247602,
#  'backup': 8.844444240792825,
#  'backward': 8.844444240792825,
#  'bagley': 8.844444240792825,
#  'balanc': 6.718467013116808,
#  'ballist': 6.327222394556876,
#  'band': 8.105384749247602,
#  'bandwidth': 8.844444240792825,
#  'bang': 8.844444240792825,
#  'bank': 7.617860981241781,
#  'bar': 8.105384749247602,
#  'barrel': 8.844444240792825,
#  'barrier': 8.105384749247602,
#  'base': 2.362391957890453,
#  'basetyp': 8.844444240792825,
#  'basi': 4.164424823065223,
#  'basic': 4.960675490622213,
#  'beam': 6.961581237141928,
#  'bear': 6.961581237141928,
#  'becam': 8.844444240792825,
#  'becom': 4.436677413683941,
#  'bedford': 8.105384749247602,
#  'began': 7.617860981241781,
#  'begin': 6.327222394556876,
#  'begun': 8.105384749247602,
#  'behav': 6.509906931997541,
#  'behavior': 4.892930653763678,
#  'behaviour': 6.327222394556876,
#  'behind': 4.123224735299552,
#  'believ': 6.509906931997541,
#  'bell': 8.844444240792825,
#  'belltyp': 8.844444240792825,
#  'belong': 8.844444240792825,
#  'belotserkovskii': 8.105384749247602,
#  'belt': 8.844444240792825,
#  'bend': 5.4456156489388094,
#  'bendingtors': 8.844444240792825,
#  'beneath': 8.844444240792825,
#  'benefici': 7.617860981241781,
#  'ber': 8.844444240792825,
#  'bergdolt': 8.844444240792825,
#  'berger': 8.844444240792825,
#  'bernoulli': 8.844444240792825,
#  'bertram': 8.844444240792825,
#  'bessel': 8.105384749247602,
#  'best': 6.961581237141928,
#  'beta': 8.844444240792825,
#  'better': 5.8847677847103785,
#  'bevel': 8.844444240792825,
#  'beyond': 5.8847677847103785,
#  'bibliographi': 8.105384749247602,
#  'biconvex': 7.617860981241781,
#  'biharmon': 8.844444240792825,
#  'bimolecular': 8.844444240792825,
#  'binari': 7.617860981241781,
#  'biot': 7.253190908704789,
#  'blade': 5.4456156489388094,
#  'blasiu': 5.762348815644129,
#  'blast': 5.649189634077765,
#  'bleed': 6.961581237141928,
#  'blend': 8.844444240792825,
#  'blockag': 6.961581237141928,
#  'blow': 6.718467013116808,
#  'blowout': 8.844444240792825,
#  'bluff': 6.961581237141928,
#  'bluish': 8.844444240792825,
#  'blunt': 2.984795128388668,
#  'blunter': 8.844444240792825,
#  'bluntnos': 8.105384749247602,
#  'blunttrail': 8.844444240792825,
#  'board': 8.844444240792825,
#  'boat': 8.844444240792825,
#  'boattail': 7.253190908704789,
#  'bodi': 1.6440284415856738,
#  'bogdonoff': 8.105384749247602,
#  'boltzmann': 8.105384749247602,
#  'bomb': 8.844444240792825,
#  'bond': 8.844444240792825,
#  'book': 8.844444240792825,
#  'booster': 8.844444240792825,
#  'bore': 8.844444240792825,
#  'born': 8.105384749247602,
#  'bottom': 8.844444240792825,
#  'bound': 7.253190908704789,
#  'boundari': 0.5234513241762111,
#  'boundarylay': 4.892930653763678,
#  'bow': 6.164642333361623,
#  'box': 8.105384749247602,
#  'bracket': 8.844444240792825,
#  'brake': 8.105384749247602,
#  'branch': 6.961581237141928,
#  'braunschweig': 8.844444240792825,
#  'break': 6.509906931997541,
#  'breakdown': 7.617860981241781,
#  'bridg': 8.844444240792825,
#  'brief': 5.543965128848965,
#  'briefli': 5.353280513589814,
#  'bring': 7.617860981241781,
#  'british': 7.617860981241781,
#  'broaden': 8.105384749247602,
#  'broken': 8.844444240792825,
#  'brooklyn': 8.844444240792825,
#  'brought': 7.617860981241781,
#  'brown': 8.844444240792825,
#  'btu': 8.844444240792825,
#  'bubbl': 8.105384749247602,
#  'buckl': 6.509906931997541,
#  'buffet': 7.253190908704789,
#  'build': 8.105384749247602,
#  'builtup': 8.844444240792825,
#  'bulent': 8.844444240792825,
#  'bulk': 7.253190908704789,
#  'buoyant': 8.105384749247602,
#  'bureau': 8.844444240792825,
#  'burger': 8.105384749247602,
#  'burn': 7.617860981241781,
#  'busemann': 7.617860981241781,
#  'butler': 8.844444240792825,
#  'buzz': 8.844444240792825,
#  'bystep': 8.844444240792825,
#  'cal': 8.844444240792825,
#  'calcul': 1.7130965192984116,
#  'calculu': 7.617860981241781,
#  'calibr': 6.164642333361623,
#  'california': 7.617860981241781,
#  'call': 6.327222394556876,
#  'calor': 7.617860981241781,
#  'camber': 5.762348815644129,
#  'camera': 8.844444240792825,
#  'cannot': 5.762348815644129,
#  'cant': 8.844444240792825,
#  'cantilev': 5.8847677847103785,
#  'cap': 6.961581237141928,
#  'capabl': 7.617860981241781,
#  'capac': 6.718467013116808,
#  'capacit': 8.844444240792825,
#  'caplan': 8.844444240792825,
#  'capsul': 8.844444240792825,
#  'carbon': 7.617860981241781,
#  'care': 6.327222394556876,
#  'caret': 8.844444240792825,
#  'carri': 4.436677413683941,
#  'carter': 8.844444240792825,
#  'cartesian': 8.105384749247602,
#  'cascad': 6.327222394556876,
#  'case': 1.4783513100901207,
#  'castigliano': 8.844444240792825,
#  'castolit': 8.844444240792825,
#  'catalyt': 8.844444240792825,
#  'categori': 8.105384749247602,
#  'caus': 4.206704850717073,
#  'cavit': 8.844444240792825,
#  'caviti': 7.617860981241781,
#  'ceas': 7.617860981241781,
#  'cell': 8.844444240792825,
#  'cent': 4.892930653763678,
#  'center': 5.762348815644129,
#  'centerlin': 8.105384749247602,
#  'centigrad': 8.844444240792825,
#  'centr': 6.164642333361623,
#  'central': 6.961581237141928,
#  'centrelin': 8.844444240792825,
#  'centrifug': 7.253190908704789,
#  'centroid': 8.844444240792825,
#  'certain': 3.5458323791244317,
#  'certainli': 8.105384749247602,
#  'certainti': 8.844444240792825,
#  'chamber': 8.844444240792825,
#  'chang': 3.329984649758421,
#  'channel': 5.8847677847103785,
#  'chap': 8.844444240792825,
#  'chapman': 6.961581237141928,
#  'chapter': 8.844444240792825,
#  'charact': 6.018133928725235,
#  'character': 5.8847677847103785,
#  'characterist': 2.824130634808431,
#  'characteristi': 8.844444240792825,
#  'charg': 6.164642333361623,
#  'chart': 6.018133928725235,
#  'charter': 8.844444240792825,
#  'check': 6.164642333361623,
#  'chem': 8.844444240792825,
#  'chemic': 4.892930653763678,
#  'chemisorpt': 8.844444240792825,
#  'chemistri': 8.844444240792825,
#  'cheng': 8.844444240792825,
#  'chernyi': 8.844444240792825,
#  'cheski': 8.844444240792825,
#  'chester': 8.844444240792825,
#  'chief': 8.105384749247602,
#  'chiefli': 8.844444240792825,
#  'child': 8.844444240792825,
#  'choic': 6.509906931997541,
#  'choke': 7.617860981241781,
#  'choleski': 8.844444240792825,
#  'choos': 7.617860981241781,
#  'chord': 5.183937091815038,
#  'chordwis': 5.762348815644129,
#  'chosen': 5.8847677847103785,
#  'circl': 7.253190908704789,
#  'circuit': 8.844444240792825,
#  'circul': 6.509906931997541,
#  'circular': 4.123224735299552,
#  'circularcylindr': 8.105384749247602,
#  'circulatori': 8.844444240792825,
#  'circumscrib': 8.105384749247602,
#  'circumst': 7.617860981241781,
#  'cite': 8.105384749247602,
#  'civil': 8.105384749247602,
#  'claim': 8.844444240792825,
#  'clamp': 6.018133928725235,
#  'class': 5.266251118517337,
#  'classic': 5.03154151728639,
#  'classif': 8.105384749247602,
#  'classifi': 8.844444240792825,
#  'classificaiton': 8.844444240792825,
#  'clear': 7.617860981241781,
#  'clearli': 6.718467013116808,
#  'climb': 8.105384749247602,
#  'close': 3.759940729889754,
#  'closedform': 8.105384749247602,
#  'closer': 7.617860981241781,
#  'closest': 8.844444240792825,
#  'cloud': 8.844444240792825,
#  'coars': 8.844444240792825,
#  'coast': 8.844444240792825,
#  'coaxial': 8.105384749247602,
#  'code': 8.844444240792825,
#  'coeffici': 2.2723886340860475,
#  'coefstant': 8.844444240792825,
#  'coincid': 8.105384749247602,
#  'cold': 6.718467013116808,
#  'colder': 8.844444240792825,
#  'cole': 8.105384749247602,
#  'collabor': 8.105384749247602,
#  'collaps': 8.844444240792825,
#  'collect': 6.718467013116808,
#  'collis': 7.253190908704789,
#  'colloc': 8.844444240792825,
#  'colour': 8.844444240792825,
#  'column': 8.844444240792825,
#  'combin': 3.5458323791244317,
#  'combust': 8.105384749247602,
#  'combut': 8.844444240792825,
#  'comment': 6.509906931997541,
#  'commerci': 8.105384749247602,
#  'committe': 7.617860981241781,
#  'common': 6.327222394556876,
#  'commonli': 6.961581237141928,
#  'commun': 8.844444240792825,
#  'compact': 8.844444240792825,
#  'compani': 8.844444240792825,
#  'companion': 8.844444240792825,
#  'compar': 2.075564921032753,
#  'comparison': 3.255443072628369,
#  'compat': 7.253190908704789,
#  'compens': 8.844444240792825,
#  'compet': 8.844444240792825,
#  'competit': 8.844444240792825,
#  'compil': 7.617860981241781,
#  'complementari': 8.105384749247602,
#  'complet': 3.604297292036601,
#  'complex': 5.762348815644129,
#  'complic': 6.327222394556876,
#  'compon': 4.34067181722806,
#  'compos': 6.961581237141928,
#  'composit': 5.649189634077765,
#  'comprehens': 8.844444240792825,
#  'compress': 2.8827912384679126,
#  'compressibleflow': 8.844444240792825,
#  'compression': 8.844444240792825,
#  'compressor': 5.353280513589814,
#  'compris': 7.253190908704789,
#  'compromis': 7.253190908704789,
#  'comput': 3.3555480623797767,
#  'concav': 8.105384749247602,
#  'conceiv': 8.844444240792825,
#  'concentr': 5.266251118517337,
#  'concept': 4.436677413683941,
#  'concern': 4.538886630173182,
#  'concis': 8.105384749247602,
#  'conclud': 4.892930653763678,
#  'conclus': 4.486954296916836,
#  'concoct': 8.844444240792825,
#  'concur': 8.844444240792825,
#  'concurr': 8.844444240792825,
#  'condamp': 8.844444240792825,
#  'condens': 8.105384749247602,
#  'condit': 1.6326824457863867,
#  'conduct': 2.6581359034741556,
#  'conductioncontrol': 8.844444240792825,
#  'cone': 3.604297292036601,
#  'conecylind': 8.105384749247602,
#  'configur': 4.705869513940396,
#  'confin': 8.105384749247602,
#  'confirm': 6.164642333361623,
#  'conflict': 7.253190908704789,
#  'confluent': 8.105384749247602,
#  'conform': 7.253190908704789,
#  'conformaltransform': 8.844444240792825,
#  'confus': 8.844444240792825,
#  'conic': 4.34067181722806,
#  'conjectur': 8.844444240792825,
#  'conjunct': 5.8847677847103785,
#  'connect': 5.353280513589814,
#  'conpress': 8.844444240792825,
#  'consequ': 5.649189634077765,
#  'conserv': 6.164642333361623,
#  'consid': 2.185930213752435,
#  'consider': 3.0058813576800096,
#  'consier': 8.844444240792825,
#  'consist': 4.34067181722806,
#  'consolid': 8.844444240792825,
#  'const': 8.844444240792825,
#  'constanc': 8.844444240792825,
#  'constant': 2.5214185055329983,
#  'constantdens': 8.844444240792825,
#  'constantproperti': 8.844444240792825,
#  'constitu': 8.105384749247602,
#  'constitut': 7.253190908704789,
#  'constrain': 8.844444240792825,
#  'constraint': 6.718467013116808,
#  'construct': 5.353280513589814,
#  'contact': 6.961581237141928,
#  'contain': 5.183937091815038,
#  'contamin': 8.105384749247602,
#  'contempl': 8.844444240792825,
#  'content': 8.844444240792825,
#  'continu': 4.648204934712976,
#  'continuum': 6.509906931997541,
#  'contour': 6.164642333361623,
#  'contract': 6.718467013116808,
#  'contrari': 7.617860981241781,
#  'contrast': 6.961581237141928,
#  'contribut': 4.960675490622213,
#  'control': 4.387948925751628,
#  'controversi': 8.105384749247602,
#  'convect': 4.387948925751628,
#  'conveni': 6.718467013116808,
#  'convent': 5.105841370565194,
#  'converg': 4.892930653763678,
#  'convergentdiverg': 8.844444240792825,
#  'convers': 6.961581237141928,
#  'convert': 7.617860981241781,
#  'convex': 8.105384749247602,
#  'convolut': 8.844444240792825,
#  'cool': 3.860773128843857,
#  'coolant': 5.649189634077765,
#  'cooper': 8.105384749247602,
#  'coordin': 5.03154151728639,
#  'cope': 8.844444240792825,
#  'core': 5.8847677847103785,
#  'cornel': 8.844444240792825,
#  'corner': 6.509906931997541,
#  'corollari': 8.844444240792825,
#  'corpuscular': 8.844444240792825,
#  'correct': 4.123224735299552,
#  'correctli': 7.253190908704789,
#  'correl': 3.8264786451084944,
#  'correlogram': 8.844444240792825,
#  'correspond': 3.461710758196434,
#  'corridor': 8.105384749247602,
#  'corrug': 8.844444240792825,
#  'cost': 8.105384749247602,
#  'couett': 6.718467013116808,
#  'could': 4.486954296916836,
#  'coundari': 8.844444240792825,
#  'counter': 8.844444240792825,
#  'counteract': 8.844444240792825,
#  'counterpart': 7.617860981241781,
#  'countri': 8.844444240792825,
#  'coupl': 5.543965128848965,
#  'cours': 6.164642333361623,
#  'cover': 5.105841370565194,
#  'cowl': 8.844444240792825,
#  'crabtre': 8.844444240792825,
#  'craft': 8.844444240792825,
#  'creep': 8.844444240792825,
#  'crest': 8.844444240792825,
#  'crew': 8.844444240792825,
#  'criteria': 6.718467013116808,
#  'criterion': 6.018133928725235,
#  'critic': 4.648204934712976,
#  'crocco': 5.8847677847103785,
#  'crop': 8.844444240792825,
#  'cross': 4.436677413683941,
#  'crosscorrel': 8.844444240792825,
#  'crossflow': 7.253190908704789,
#  'crosssect': 8.844444240792825,
#  'cruciform': 6.718467013116808,
#  'cruis': 7.617860981241781,
#  'cubic': 8.844444240792825,
#  'cure': 8.844444240792825,
#  'curl': 8.844444240792825,
#  'current': 5.266251118517337,
#  'curv': 3.860773128843857,
#  'curvatur': 4.828035174897279,
#  'cushion': 7.617860981241781,
#  'cuss': 8.844444240792825,
#  'customari': 8.105384749247602,
#  'cut': 7.617860981241781,
#  'cutout': 8.105384749247602,
#  'cycl': 7.253190908704789,
#  'cyclic': 8.844444240792825,
#  'cylind': 3.5748145453450735,
#  'cylindr': 4.892930653763678,
#  'daley': 8.844444240792825,
#  'damp': 5.266251118517337,
#  'dana': 8.844444240792825,
#  'danger': 8.844444240792825,
#  'dash': 6.718467013116808,
#  'dashin': 8.844444240792825,
#  'dashn': 8.844444240792825,
#  'dashth': 8.844444240792825,
#  'dashthat': 8.844444240792825,
#  'data': 2.6230759624775755,
#  'date': 8.105384749247602,
#  'day': 6.961581237141928,
#  'dead': 7.617860981241781,
#  'deal': 5.183937091815038,
#  'dealt': 6.718467013116808,
#  'deby': 8.844444240792825,
#  'decay': 6.018133928725235,
#  'deceler': 6.018133928725235,
#  'decid': 7.617860981241781,
#  'decidedli': 8.844444240792825,
#  'decis': 8.844444240792825,
#  'declassifi': 8.844444240792825,
#  'declin': 8.844444240792825,
#  'decreas': 4.043840620391032,
#  'deduc': 5.543965128848965,
#  'deduct': 8.105384749247602,
#  'deep': 8.844444240792825,
#  'defect': 8.844444240792825,
#  'defenc': 8.105384749247602,
#  'defici': 8.105384749247602,
#  'deficit': 8.844444240792825,
#  'defin': 4.538886630173182,
#  'definit': 6.164642333361623,
#  'deflect': 4.592592941845535,
#  'deform': 7.253190908704789,
#  'deg': 7.617860981241781,
#  'degener': 8.105384749247602,
#  'degrad': 8.844444240792825,
#  'degre': 4.387948925751628,
#  'degreek': 8.844444240792825,
#  'deisgn': 8.844444240792825,
#  'delay': 6.509906931997541,
#  'delimit': 8.844444240792825,
#  'delta': 5.353280513589814,
#  'demand': 8.105384749247602,
#  'demarc': 8.844444240792825,
#  'demonstr': 4.960675490622213,
#  'denc': 8.844444240792825,
#  'denot': 6.509906931997541,
#  'dens': 8.844444240792825,
#  'denser': 8.844444240792825,
#  'densiti': 3.5458323791244317,
#  'depart': 8.844444240792825,
#  'departur': 6.961581237141928,
#  'depend': 3.3555480623797767,
#  'deposit': 8.844444240792825,
#  'depress': 8.844444240792825,
#  'depth': 6.509906931997541,
#  'deriv': 2.4245630070971633,
#  'descend': 7.617860981241781,
#  'descent': 8.105384749247602,
#  'describ': 3.0272103071593786,
#  'descript': 5.353280513589814,
#  'design': 3.381489323053626,
#  'desir': 5.266251118517337,
#  'desk': 8.844444240792825,
#  'despit': 8.844444240792825,
#  'destabil': 6.961581237141928,
#  'destal': 8.105384749247602,
#  'detach': 5.266251118517337,
#  'detail': 3.5458323791244317,
#  'detect': 6.718467013116808,
#  'deterior': 7.617860981241781,
#  'determin': 2.0487755147853353,
#  'detra': 8.844444240792825,
#  'detriment': 8.105384749247602,
#  'deuc': 8.105384749247602,
#  'develop': 2.1163339247140476,
#  'deviat': 5.762348815644129,
#  'devic': 7.253190908704789,
#  'devis': 6.961581237141928,
#  'devot': 7.253190908704789,
#  'diagon': 8.844444240792825,
#  'diagram': 6.961581237141928,
#  'diam': 8.844444240792825,
#  'diamet': 4.387948925751628,
#  'diamond': 8.105384749247602,
#  'diatom': 7.253190908704789,
#  'dicsov': 8.844444240792825,
#  'dielectr': 8.844444240792825,
#  'differ': 2.605773905892296,
#  'differenti': 3.9315718281139977,
#  'difficult': 5.8847677847103785,
#  'difficulti': 5.4456156489388094,
#  'diffus': 4.648204934712976,
#  'digit': 6.509906931997541,
#  'dimens': 6.327222394556876,
#  'dimension': 2.25774288023373,
#  'dimensionless': 5.649189634077765,
#  'diminish': 6.509906931997541,
#  'dioxid': 8.105384749247602,
#  'dirac': 8.844444240792825,
#  'direct': 3.3555480623797767,
#  'directli': 5.266251118517337,
#  'director': 8.844444240792825,
#  'disadvantag': 8.105384749247602,
#  'disagr': 7.617860981241781,
#  'disappear': 7.253190908704789,
#  'disc': 8.105384749247602,
#  'discern': 8.844444240792825,
#  'discharg': 7.253190908704789,
#  'disclos': 8.844444240792825,
#  'discontinu': 5.8847677847103785,
#  'discov': 7.617860981241781,
#  'discover': 8.844444240792825,
#  'discoveri': 8.844444240792825,
#  'discrep': 6.327222394556876,
#  'discret': 7.617860981241781,
#  'discuss': 2.075564921032753,
#  'disk': 7.253190908704789,
#  'dismiss': 8.844444240792825,
#  'dispers': 8.105384749247602,
#  'displac': 4.592592941845535,
#  'display': 7.617860981241781,
#  'dispos': 8.844444240792825,
#  'disregard': 8.105384749247602,
#  'dissip': 5.543965128848965,
#  'dissoci': 4.592592941845535,
#  'dissociationrecombin': 8.844444240792825,
#  'distanc': 3.3555480623797767,
#  'distant': 8.844444240792825,
#  'distinct': 6.961581237141928,
#  'distinctli': 8.105384749247602,
#  'distinguish': 7.617860981241781,
#  'distort': 6.961581237141928,
#  'distribut': 1.3211974313919324,
#  'disturb': 4.123224735299552,
#  'diurnal': 8.105384749247602,
#  'dive': 8.844444240792825,
#  'diverg': 5.266251118517337,
#  'divers': 8.844444240792825,
#  'divid': 6.018133928725235,
#  'divis': 8.105384749247602,
#  'doctor': 8.844444240792825,
#  'domain': 7.617860981241781,
#  'domin': 6.718467013116808,
#  'done': 6.509906931997541,
#  'doppler': 8.844444240792825,
#  'dorodnitsyn': 8.844444240792825,
#  'dorodnitzyn': 8.844444240792825,
#  'doubl': 5.649189634077765,
#  'doublet': 8.105384749247602,
#  'doubt': 7.253190908704789,
#  'downstream': 4.164424823065223,
#  'downward': 8.105384749247602,
#  'downwash': 6.164642333361623,
#  'drag': 3.0058813576800096,
#  'drastic': 7.617860981241781,
#  'draw': 7.617860981241781,
#  'drawn': 6.961581237141928,
#  'drew': 8.844444240792825,
#  'dri': 8.844444240792825,
#  'drift': 8.844444240792825,
#  'drive': 8.844444240792825,
#  'driven': 7.617860981241781,
#  'droop': 8.844444240792825,
#  'drop': 6.961581237141928,
#  'dropoff': 8.844444240792825,
#  'drum': 8.844444240792825,
#  'dryden': 8.105384749247602,
#  'dual': 8.844444240792825,
#  'duct': 6.164642333361623,
#  'due': 3.092720694961435,
#  'dufour': 8.844444240792825,
#  'duplic': 8.844444240792825,
#  'durat': 7.617860981241781,
#  'dyke': 7.253190908704789,
#  'dynam': 4.592592941845535,
#  'earli': 6.018133928725235,
#  'earlier': 5.649189634077765,
#  'earth': 5.543965128848965,
#  'eas': 8.844444240792825,
#  'easi': 8.105384749247602,
#  'easier': 8.844444240792825,
#  'easili': 7.253190908704789,
#  'eccentr': 6.961581237141928,
#  'echo': 8.844444240792825,
#  'eckert': 7.617860981241781,
#  'econom': 8.105384749247602,
#  'eddi': 6.718467013116808,
#  'edelfelt': 8.844444240792825,
#  'edg': 2.5547415582182285,
#  'edgewis': 8.844444240792825,
#  'edpm': 8.844444240792825,
#  'educ': 8.844444240792825,
#  'effect': 0.5320852108431333,
#  'efficaci': 8.844444240792825,
#  'effici': 5.762348815644129,
#  'effort': 6.509906931997541,
#  'effus': 8.844444240792825,
#  'egger': 8.844444240792825,
#  'eigenvalu': 8.105384749247602,
#  'eight': 8.844444240792825,
#  'eighth': 8.844444240792825,
#  'einbind': 8.844444240792825,
#  'either': 4.250126744114718,
#  'elabor': 8.105384749247602,
#  'elast': 5.543965128848965,
#  'electr': 4.538886630173182,
#  'electro': 8.844444240792825,
#  'electrod': 8.844444240792825,
#  'electroform': 8.844444240792825,
#  'electrohydrodynam': 8.844444240792825,
#  'electromagnet': 6.961581237141928,
#  'electron': 6.018133928725235,
#  'electrostat': 8.844444240792825,
#  'eleg': 8.844444240792825,
#  'element': 5.266251118517337,
#  'elementari': 6.961581237141928,
#  'elimin': 6.327222394556876,
#  'elliott': 8.844444240792825,
#  'ellips': 8.844444240792825,
#  'ellipsoid': 7.253190908704789,
#  'ellipt': 5.543965128848965,
#  'elsewher': 8.105384749247602,
#  'embed': 8.844444240792825,
#  'embrac': 8.105384749247602,
#  'emerg': 8.844444240792825,
#  'emiss': 6.961581237141928,
#  'emit': 7.253190908704789,
#  'emmon': 8.105384749247602,
#  'emphas': 5.762348815644129,
#  'emphasi': 6.327222394556876,
#  'emphasis': 8.844444240792825,
#  'empir': 4.765751220973765,
#  'employ': 4.294757893721893,
#  'enabl': 6.327222394556876,
#  'enc': 8.844444240792825,
#  'enclos': 7.617860981241781,
#  'encompass': 7.617860981241781,
#  'encount': 6.164642333361623,
#  'encourag': 8.105384749247602,
#  'end': 5.649189634077765,
#  'endors': 8.844444240792825,
#  'endplat': 8.844444240792825,
#  'energi': 3.634300021698419,
#  'enforc': 8.844444240792825,
#  'engag': 8.844444240792825,
#  'engin': 5.4456156489388094,
#  'england': 8.844444240792825,
#  'enhanc': 8.844444240792825,
#  'eniac': 8.844444240792825,
#  'enjoy': 8.844444240792825,
#  'enlarg': 8.105384749247602,
#  'enlighten': 8.844444240792825,
#  'enough': 6.961581237141928,
#  'enquiri': 8.844444240792825,
#  'ensu': 8.844444240792825,
#  'ensur': 8.844444240792825,
#  'entail': 8.105384749247602,
#  'enter': 5.762348815644129,
#  'enthalp': 8.844444240792825,
#  'enthalpi': 5.03154151728639,
#  'entir': 4.486954296916836,
#  'entireti': 8.844444240792825,
#  'entitl': 8.844444240792825,
#  'entrain': 8.844444240792825,
#  'entranc': 8.105384749247602,
#  'entri': 5.4456156489388094,
#  'entropi': 6.718467013116808,
#  'envelop': 7.253190908704789,
#  'environ': 7.253190908704789,
#  'environment': 8.844444240792825,
#  'epoxi': 8.844444240792825,
#  'equal': 4.892930653763678,
#  'equat': 1.2906508997643185,
#  'equatori': 8.844444240792825,
#  'equilater': 8.844444240792825,
#  'equilibr': 8.844444240792825,
#  'equilibria': 8.844444240792825,
#  'equilibrium': 4.164424823065223,
#  'equip': 7.253190908704789,
#  'equival': 5.266251118517337,
#  'eratur': 8.844444240792825,
#  'erfc': 8.844444240792825,
#  'erickson': 8.844444240792825,
#  'eros': 8.844444240792825,
#  'error': 5.353280513589814,
#  'escap': 8.844444240792825,
#  'especi': 5.353280513589814,
#  'essenc': 8.105384749247602,
#  'essenti': 4.436677413683941,
#  'establish': 4.892930653763678,
#  'estim': 3.634300021698419,
#  'etc': 6.718467013116808,
#  'eter': 8.844444240792825,
#  'etud': 8.844444240792825,
#  'eucken': 8.844444240792825,
#  'euler': 6.718467013116808,
#  'eulerian': 8.844444240792825,
#  'evalu': 4.164424823065223,
#  'evapor': 8.105384749247602,
#  'even': 4.892930653763678,
#  'event': 8.105384749247602,
#  'eventu': 8.844444240792825,
#  'everi': 7.253190908704789,
#  'everywher': 8.844444240792825,
#  'evid': 5.183937091815038,
#  'evolv': 8.844444240792825,
#  'exact': 3.092720694961435,
#  'exactli': 6.164642333361623,
#  'examin': 4.436677413683941,
#  'exampl': 3.3047869620659682,
#  'exce': 7.617860981241781,
#  'exceed': 5.8847677847103785,
#  'excel': 6.164642333361623,
#  'except': 4.043840620391032,
#  'excess': 6.718467013116808,
#  'exchang': 8.844444240792825,
#  'excit': 6.018133928725235,
#  'exclud': 7.617860981241781,
#  'excresc': 8.844444240792825,
#  'excus': 8.844444240792825,
#  'exercis': 8.844444240792825,
#  'exert': 7.253190908704789,
#  'exhaust': 6.718467013116808,
#  'exhibit': 6.018133928725235,
#  'exist': 3.3555480623797767,
#  'exit': 5.543965128848965,
#  'expand': 6.164642333361623,
#  'expans': 4.005555243833171,
#  'expect': 4.892930653763678,
#  'expenditur': 8.105384749247602,
#  'experi': 3.070622981635675,
#  'experienc': 7.617860981241781,
#  'experiment': 1.6554205955060055,
#  'explain': 6.164642333361623,
#  'explan': 7.617860981241781,
#  'explicit': 6.718467013116808,
#  'explicitli': 7.253190908704789,
#  'exploit': 8.844444240792825,
#  'explor': 7.617860981241781,
#  'exploratori': 7.253190908704789,
#  'explos': 7.617860981241781,
#  'expon': 8.105384749247602,
#  'exponenti': 6.718467013116808,
#  'exponentiallyfici': 8.844444240792825,
#  'expos': 6.509906931997541,
#  'exposit': 8.844444240792825,
#  'exposur': 8.844444240792825,
#  'express': 3.1150891353622123,
#  ...}

# %% [markdown]
# Creating TF-IDF table

# %%
def TF(wordDict):
    
#     max_fi = 0
#     for key, val in wordDict.items():
#         if val>max_fi:
#             max_fi = val
    
    newDict = {}
    for key, val in wordDict.items():
        if val>0:
            
            #log normalization
            newDict[key] = 1+ math.log(val,2)
            
            
            #double normalization K
            #newDict[key] = 0.5 * ((0.5*val)/ max_fi)
    
    return newDict

# %%
dictList = [dict() for x in range(N)]
for i in range(N):
    dictList[i] = dict.fromkeys(wordSet, 0) 
    
    for word in BOW('prep_corpus/doc'+str(i+1)):
        dictList[i][word]+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-10c56a467f6d> in <module>
#       1 dictList = [dict() for x in range(N)]
#       2 for i in range(N):
# ----> 3     dictList[i] = dict.fromkeys(wordSet, 0)
#       4
#       5     for word in BOW('prep_corpus/doc'+str(i+1)):
#
# NameError: name 'wordSet' is not defined

# %%
def computeIDF(dictList):
    idfDict = {}
    N = len(dictList)
    print(N)
    
    idfDict = dict.fromkeys(dictList[0].keys(), 0)
    
    for doc in dictList:
        for word, val in doc.items():
            if val > 0:
                idfDict[word] += 1
    
    for word, val in idfDict.items():
        #inverse frequency
        idfDict[word] = math.log((N / float(val)), 2)
        
        #inverse frequency smooth
        #idfDict[word] = math.log((1+(N/float(val))), 2)
        
        #probabilistic inverse frequency
        #idfDict[word] = math.log(((N-val)/val), 2)
        
    return idfDict

# %%
idfs = computeIDF(dictList)
idfs

# %%
def computeTFIDF(tfBow, idfs):
    tfidf = {}
    for word, val in tfBow.items():
        tfidf[word] = val*idfs[word]
    return tfidf

# %%
finalTF = [dict() for x in range(N)]
finalTFIDF = [dict() for x in range(N)]
for i in range(N):
    finalTF[i] = TF(dictList[i])
    
finalTF

# %%
for i in range(N):
    finalTFIDF[i] = computeTFIDF(finalTF[i], idfs)

# %%
import pandas as pd
df = pd.DataFrame(finalTFIDF)
df

# %%
import numpy as np

# %%
df = df.replace(np.nan, 0)
df

# %%
query = "flow past"
queryTerms = query.split(' ')
for i in range(len(queryTerms)):
    queryTerms[i] = queryTerms[i].lower()
    
queryTerms

# %%
queryCount = dict.fromkeys(queryTerms, 0) 
for term in queryTerms:
    queryCount[term]+=1
    
queryCount

# %% [markdown]
# BM1

# %%
result = []
for i in range(N):
    relval = 0
    for word in queryTerms:
        table_val = df.at[i, word]
        if table_val>0:
            relval=relval+int(term_matrix[word])
    
    result.append(relval)

# %%
result

# %%
ranking_dict = {}

for i in range(N):
    ranking_dict[i] = result[i]

ranking_dict

# %%
from heapq import nlargest
final_result = nlargest(3, ranking_dict, key = ranking_dict.get)
final_result

# %%
print("Top 3 documents: ")
for doc in final_result:
    print("Document", doc, ": ", result[doc])

# %%
for doc in final_result:
    loc = 'prep_corpus/doc'+str(doc+1)
    file = open(loc, 'r')
    for line in file: 
        print(line)

# %%
dictList[0]

# %%
def term_freq_factor_Fij(term, document):
    K1 = 5
    S1 = K1+1
    fij = dictList[document][term]    
    Fij = (S1 * fij)/(K1 + fij)
    
    return Fij

# %%
dictList[0]

# %%
term_freq_factor_Fij('face', 0)

# %%
all_doc_len = []
for i in range(N):
    all_doc_len.append(len(BOW('prep_corpus/doc'+str(i+1))))
    
all_doc_len

# %%
from statistics import mean
avg_doc_len = mean(all_doc_len)
avg_doc_len

# %%
def doc_len_normal(term, document):
    
    K1 = 5
    S1 = K1+1
    fij = dictList[document][term]
    doc_length = all_doc_len[document]
    
    F_dash = (S1 * fij)/(((K1 * doc_length)/avg_doc_len) + fij)
    
    return F_dash

# %%
doc_len_normal('flow', 3)

# %%
def correction_factor(document, query_length):
    K2 = 0
    doc_length = all_doc_len[document]
    G = K2 * query_length * ((avg_doc_len - doc_length)/(avg_doc_len + doc_length))
    
    return G

# %%
correction_factor(686, 2)

# %%
def term_freq_within_query(term, queryCount):
    K3 = 10
    S3 = K3 + 1
    
    Fiq = (S3 * queryCount[term])/(K3 + queryCount[term])
    
    return Fiq

# %%
term_freq_within_query('flow', queryCount)

# %%
def Bij(term, document):
    K1 = 1
    b = 0.99
    num = (K1 + 1)* dictList[document][term]
    
    den = (K1 * ((1 - b) + (b*all_doc_len[document])/avg_doc_len)) + dictList[document][term]
    
    return (num/den)

# %%
querylength = len(queryTerms)
querylength

# %%
queryTerms

# %%
BM = []
for i in range(N):
    G = correction_factor(i, querylength)
    relval = 0
    for word in queryTerms:
        table_val = df.at[i, word]
        if table_val > 0:
            #BM11
            relval = relval + doc_len_normal(word, i) * term_freq_within_query(word, queryCount) * int(term_matrix[word])
            
            #BM15
            #relval = relval + term_freq_factor_Fij(word, i) * term_freq_within_query(word, queryCount) * term_matrix[word]
    relval = G + relval
    BM.append(relval)

# %%
BM

# %%
BM_ranking = {}

for i in range(N):
    BM_ranking[i] = BM[i]

BM_ranking

# %%
final_result = nlargest(3, BM_ranking, key = BM_ranking.get)
final_result

# %%
print("Top 3 documents: ")
for doc in final_result:
    print("Document", doc, ": ", BM_ranking[doc])

# %%
for doc in final_result:
    loc = 'prep_corpus/doc'+str(doc+1)
    file = open(loc, 'r')
    for line in file: 
        print(line)

# %%
K1 = 5

# %%
BM = []
for i in range(N):
    relval = 0
    for word in queryTerms:
        table_val = df.at[i, word]
        if table_val > 0:
            #Simpler BM15
            #relval = relval + (((K1+1)* dictList[i][word])/K1 + dictList[i][word]) * term_matrix[word]
            
            #Simpler BM11
            relval = relval + (((K1+1)* dictList[i][word])/((K1*all_doc_len[i])/avg_doc_len) + dictList[i][word])* int(term_matrix[word])
            
            #BM25
            #relval += Bij(term, i) * term_matrix[word]
    relval = G + relval
    BM.append(relval)

# %%
result = sorted(BM_ranking.items(), key = lambda kv:(kv[1], kv[0]))

# %%
result[-3:]
